# %%
# %matplotlib inline
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
import pandas as pd
import numpy as np
import sqlite3
from main_db_script import db_filename
from hr_db_scripts.main_db_script import get_table_for_variable_code, get_db_table_as_df

# %%
def round_down_near_24(datetimes): # round down the times near midnight so the tide levels stay on the correct day
    close_time_idx = datetimes.indexer_between_time('23:29', '23:59')
    adjusted_times = datetimes[close_time_idx] - pd.Timedelta(minutes=15)
    dt = pd.Series(datetimes)
    dt[close_time_idx] = adjusted_times
    dt = pd.DatetimeIndex(dt)
    return dt

# %%
def cln_n_rnd_times(df):
    for i in range(df.shape[1]):
        datetimes = df.iloc[:, i]
        times = pd.DatetimeIndex(datetimes)
        rnd_dn = round_down_near_24(times)
        df.iloc[:, i] = rnd_dn
    return df

# %%
def pivot_dv_df(df):
    return df.pivot(columns='SiteID', values='Value')

# %%
def rename_cols(df, var_abbrev):
    if var_abbrev != "":
        new_df = df.copy()
        cols = df.columns.tolist()
        new_cols = ['{}-{}'.format(var_abbrev, c) for c in cols]
        new_df.columns = new_cols
        return new_df
    else:
        return df

# %%
def filter_max_rain_time_dfs(rain_daily_df, time_df):
    timemx_filt = pd.DataFrame(np.where(rain_daily_df>0, time_df, np.datetime64('NaT')))
    timemx_filt.columns = time_df.columns
    timemx_filt.index = time_df.index
    return timemx_filt

# %%
def tide_when_rain_max(rn_mx_time_df):
    td_df = get_table_for_variable_code('six_min_tide')
    td_df = pivot_dv_df(td_df)
    td_df = td_df.resample('15T').mean()
    rn_mx_time_rnd = cln_n_rnd_times(rn_mx_time_df)
    l = []
    for c in rn_mx_time_rnd.columns:
        times = rn_mx_time_rnd.loc[:, c]
        tides = td_df.loc[times].resample('D').max()
        rain_var = c.split('_')[0]
        rain_site = c.split('-')[-1]
        new_cols = ['{}-{}_td-{}'.format(rain_var, rain_site, col) for col in tides.columns]
        tides.columns = new_cols
        l.append(tides)
    new_df = pd.concat(l, axis=1)
    new_df.sort_index(inplace=True)
    return new_df

# %%
def daily_pivot_table(var_code, agg_function, abbreviation):
    df = get_table_for_variable_code(var_code)
    dfp = pivot_dv_df(df)
    dfd = dfp.resample('D')
    aggrd = dfd.agg(agg_function)
    rnmed = rename_cols(aggrd, abbreviation)
    return rnmed

# %%
sites = get_db_table_as_df('sites')

# %% [markdown]
# #  Rainfall

# %%
# get rainfall data at 15 min interval
rain_df = get_table_for_variable_code('rainfall')

# %% [markdown]
# ## Daily Rainfall

# %%
rain_daily15 = daily_pivot_table('rainfall', np.sum, '')
rain_daily = daily_pivot_table('daily_rainfall', np.sum, '')
rain_daily_comb_no_name = pd.concat([rain_daily, rain_daily15], axis=1)
rain_daily_comb_named = rename_cols(rain_daily_comb_no_name, 'rd')
rain_daily_comb_named.head()
# Out:
#             rd-19  rd-20  rd-1  rd-2  rd-7  rd-11  rd-12  rd-13  rd-14  rd-15  \
# Datetime
# 2010-01-01   0.01   0.01   NaN   NaN  0.05   0.03   0.06   0.02   0.01   0.01
# 2010-01-02   0.00   0.00   NaN   NaN  0.00   0.01   0.00   0.00   0.00   0.00
# 2010-01-03   0.00   0.00   NaN   NaN  0.00   0.00   0.00   0.02   0.00   0.00
# 2010-01-04   0.00   0.00   NaN   NaN  0.10   0.10   0.00   0.11   0.00   0.00
# 2010-01-05   0.00   0.00   NaN   NaN  0.00   0.00   0.00   0.00   0.12   0.00
#
#             rd-16  rd-21
# Datetime
# 2010-01-01   0.02   0.03
# 2010-01-02   0.00   0.00
# 2010-01-03   0.00   0.00
# 2010-01-04   0.00   0.00
# 2010-01-05   0.00   0.11

# %% [markdown]
# ## Hourly Rainfall

# %%
rain15 = pivot_dv_df(rain_df)
rain_hourly_totals = rain15.rolling(window='H').sum()
rhr_mx = rain_hourly_totals.resample('D').max()
rhr_mx = rename_cols(rhr_mx, 'rhrmx')
rhr_mx.head()
# Out:
#             rhrmx-1  rhrmx-2  rhrmx-7  rhrmx-11  rhrmx-12  rhrmx-13  rhrmx-14  \
# Datetime
# 2010-01-01      NaN      NaN     0.04      0.01      0.04      0.01      0.01
# 2010-01-02      NaN      NaN     0.00      0.01      0.00      0.00      0.00
# 2010-01-03      NaN      NaN     0.00      0.00      0.00      0.02      0.00
# 2010-01-04      NaN      NaN     0.10      0.10      0.00      0.11      0.00
# 2010-01-05      NaN      NaN     0.00      0.00      0.00      0.00      0.12
#
#             rhrmx-15  rhrmx-16  rhrmx-21
# Datetime
# 2010-01-01      0.01      0.01      0.02
# 2010-01-02      0.00      0.00      0.00
# 2010-01-03      0.00      0.00      0.00
# 2010-01-04      0.00      0.00      0.00
# 2010-01-05      0.00      0.00      0.11

# %%
rhr_timemx = rain_hourly_totals.groupby(pd.TimeGrouper('D')).idxmax()
rhr_timemx = rename_cols(rhr_timemx, 'rhr_mxtime')
rhr_timemx = filter_max_rain_time_dfs(rain_daily15, rhr_timemx)
rhr_timemx.head()
# Out:
#            rhr_mxtime-1 rhr_mxtime-2        rhr_mxtime-7       rhr_mxtime-11  \
# Datetime
# 2010-01-01          NaT          NaT 2010-01-01 22:45:00 2010-01-01 00:15:00
# 2010-01-02          NaT          NaT                 NaT 2010-01-02 13:15:00
# 2010-01-03          NaT          NaT                 NaT                 NaT
# 2010-01-04          NaT          NaT 2010-01-04 13:30:00 2010-01-04 13:00:00
# 2010-01-05          NaT          NaT                 NaT                 NaT
#
#                  rhr_mxtime-12       rhr_mxtime-13       rhr_mxtime-14  \
# Datetime
# 2010-01-01 2010-01-01 23:00:00 2010-01-01 00:45:00 2010-01-01 00:15:00
# 2010-01-02                 NaT                 NaT                 NaT
# 2010-01-03                 NaT 2010-01-03 07:00:00                 NaT
# 2010-01-04                 NaT 2010-01-04 12:45:00                 NaT
# 2010-01-05                 NaT                 NaT 2010-01-05 10:15:00
#
#                  rhr_mxtime-15       rhr_mxtime-16       rhr_mxtime-21
# Datetime
# 2010-01-01 2010-01-01 05:00:00 2010-01-01 00:45:00 2010-01-01 23:00:00
# 2010-01-02                 NaT                 NaT                 NaT
# 2010-01-03                 NaT                 NaT                 NaT
# 2010-01-04                 NaT                 NaT                 NaT
# 2010-01-05                 NaT                 NaT 2010-01-05 10:30:00

# %% [markdown]
# ## 15-min max rainfall

# %%
r15_mx = rain15.resample('D').max()
r15_mx = rename_cols(r15_mx, 'r15mx')
r15_mx.head()
# Out:
#             r15mx-1  r15mx-2  r15mx-7  r15mx-11  r15mx-12  r15mx-13  r15mx-14  \
# Datetime
# 2010-01-01      NaN      NaN     0.02      0.01      0.02      0.01      0.01
# 2010-01-02      NaN      NaN     0.00      0.01      0.00      0.00      0.00
# 2010-01-03      NaN      NaN     0.00      0.00      0.00      0.02      0.00
# 2010-01-04      NaN      NaN     0.10      0.10      0.00      0.11      0.00
# 2010-01-05      NaN      NaN     0.00      0.00      0.00      0.00      0.12
#
#             r15mx-15  r15mx-16  r15mx-21
# Datetime
# 2010-01-01      0.01      0.01      0.02
# 2010-01-02      0.00      0.00      0.00
# 2010-01-03      0.00      0.00      0.00
# 2010-01-04      0.00      0.00      0.00
# 2010-01-05      0.00      0.00      0.11

# %%
r15_timemx = rain15.groupby(pd.TimeGrouper('D')).idxmax()
r15_timemx = rename_cols(r15_timemx, 'r15_mxtime')
r15_timemx = filter_max_rain_time_dfs(rain_daily15, r15_timemx)
r15_timemx.head()
# Out:
#            r15_mxtime-1 r15_mxtime-2        r15_mxtime-7       r15_mxtime-11  \
# Datetime
# 2010-01-01          NaT          NaT 2010-01-01 22:30:00 2010-01-01 00:15:00
# 2010-01-02          NaT          NaT                 NaT 2010-01-02 13:15:00
# 2010-01-03          NaT          NaT                 NaT                 NaT
# 2010-01-04          NaT          NaT 2010-01-04 13:30:00 2010-01-04 13:00:00
# 2010-01-05          NaT          NaT                 NaT                 NaT
#
#                  r15_mxtime-12       r15_mxtime-13       r15_mxtime-14  \
# Datetime
# 2010-01-01 2010-01-01 22:45:00 2010-01-01 00:45:00 2010-01-01 00:15:00
# 2010-01-02                 NaT                 NaT                 NaT
# 2010-01-03                 NaT 2010-01-03 07:00:00                 NaT
# 2010-01-04                 NaT 2010-01-04 12:45:00                 NaT
# 2010-01-05                 NaT                 NaT 2010-01-05 10:15:00
#
#                  r15_mxtime-15       r15_mxtime-16       r15_mxtime-21
# Datetime
# 2010-01-01 2010-01-01 05:00:00 2010-01-01 00:45:00 2010-01-01 23:00:00
# 2010-01-02                 NaT                 NaT                 NaT
# 2010-01-03                 NaT                 NaT                 NaT
# 2010-01-04                 NaT                 NaT                 NaT
# 2010-01-05                 NaT                 NaT 2010-01-05 10:30:00

# %% [markdown]
# ### Rain prev 3 days

# %%
rain_prev_3_days = rain_daily_comb_no_name.shift(1).rolling(window=3).sum()
rain_prev_3_days = rename_cols(rain_prev_3_days, 'r3d')
rain_prev_3_days.head()
# Out:
#             r3d-19  r3d-20  r3d-1  r3d-2  r3d-7  r3d-11  r3d-12  r3d-13  \
# Datetime
# 2010-01-01     NaN     NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 2010-01-02     NaN     NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 2010-01-03     NaN     NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 2010-01-04    0.01    0.01    NaN    NaN   0.05    0.04    0.06    0.04
# 2010-01-05    0.00    0.00    NaN    NaN   0.10    0.11    0.00    0.13
#
#             r3d-14  r3d-15  r3d-16  r3d-21
# Datetime
# 2010-01-01     NaN     NaN     NaN     NaN
# 2010-01-02     NaN     NaN     NaN     NaN
# 2010-01-03     NaN     NaN     NaN     NaN
# 2010-01-04    0.01    0.01    0.02    0.03
# 2010-01-05    0.00    0.00    0.00    0.00

# %% [markdown]
# #  Groundwater

# %%
gw_df = daily_pivot_table('shallow_well_depth', np.mean, 'gw_av')
gw_df.head()
# Out:
#              gw_av-4   gw_av-5  gw_av-6   gw_av-8   gw_av-9  gw_av-10  \
# Datetime
# 2010-01-01  0.181510  3.924140      NaN  6.050129  2.858511  3.167374
# 2010-01-02  0.051690  3.548121      NaN  5.990354  2.745979  3.238457
# 2010-01-03 -0.075826  3.103997      NaN  5.910525  2.650683  3.127058
# 2010-01-04 -0.186996  2.882649      NaN  5.770411  2.579872  2.990989
# 2010-01-05 -0.251922  2.772379      NaN  5.648158  2.538736  2.873044
#
#             gw_av-11
# Datetime
# 2010-01-01  3.509806
# 2010-01-02  3.637924
# 2010-01-03  3.511233
# 2010-01-04  3.348661
# 2010-01-05  3.232544

# %% [markdown]
# #  Tide

# %% [markdown]
# ## Average daily tide

# %%
tide_df = daily_pivot_table('six_min_tide', np.mean, 'td_av')
tide_df.head()
# Out:
#             td_av-17  td_av-18
# Datetime
# 2010-01-01  0.675800  0.679987
# 2010-01-02  0.604608  0.707200
# 2010-01-03 -0.608692 -0.579467
# 2010-01-04 -0.515733 -0.522700
# 2010-01-05  0.020037  0.017379

# %% [markdown]
# ##  Tide when rain is at max

# %%
td_r15mx = tide_when_rain_max(r15_timemx)
td_r15mx.head()
# Out:
#             r15-1_td-17  r15-1_td-18  r15-2_td-17  r15-2_td-18  r15-7_td-17  \
# Datetime
# 2010-01-01          NaN          NaN          NaN          NaN     1.814333
# 2010-01-02          NaN          NaN          NaN          NaN          NaN
# 2010-01-03          NaN          NaN          NaN          NaN          NaN
# 2010-01-04          NaN          NaN          NaN          NaN     0.729333
# 2010-01-05          NaN          NaN          NaN          NaN          NaN
#
#             r15-7_td-18  r15-11_td-17  r15-11_td-18  r15-12_td-17  \
# Datetime
# 2010-01-01        2.148        -0.246        -0.092        1.8375
# 2010-01-02          NaN         0.912         1.273           NaN
# 2010-01-03          NaN           NaN           NaN           NaN
# 2010-01-04        0.919         0.901         1.135           NaN
# 2010-01-05          NaN           NaN           NaN           NaN
#
#             r15-12_td-18  r15-13_td-17  r15-13_td-18  r15-14_td-17  \
# Datetime
# 2010-01-01        2.0505     -0.567500     -0.503500       -0.2460
# 2010-01-02           NaN           NaN           NaN           NaN
# 2010-01-03           NaN     -0.869333     -1.160333           NaN
# 2010-01-04           NaN      0.968000      1.240500           NaN
# 2010-01-05           NaN           NaN           NaN        0.6005
#
#             r15-14_td-18  r15-15_td-17  r15-15_td-18  r15-16_td-17  \
# Datetime
# 2010-01-01        -0.092     -0.049333        -0.431       -0.5675
# 2010-01-02           NaN           NaN           NaN           NaN
# 2010-01-03           NaN           NaN           NaN           NaN
# 2010-01-04           NaN           NaN           NaN           NaN
# 2010-01-05         0.530           NaN           NaN           NaN
#
#             r15-16_td-18  r15-21_td-17  r15-21_td-18
# Datetime
# 2010-01-01       -0.5035      1.836333      1.962000
# 2010-01-02           NaN           NaN           NaN
# 2010-01-03           NaN           NaN           NaN
# 2010-01-04           NaN           NaN           NaN
# 2010-01-05           NaN      0.772000      0.740333

# %%
td_rhrmx = tide_when_rain_max(rhr_timemx)
td_rhrmx.head()
# Out:
#             rhr-1_td-17  rhr-1_td-18  rhr-2_td-17  rhr-2_td-18  rhr-7_td-17  \
# Datetime
# 2010-01-01          NaN          NaN          NaN          NaN     1.837500
# 2010-01-02          NaN          NaN          NaN          NaN          NaN
# 2010-01-03          NaN          NaN          NaN          NaN          NaN
# 2010-01-04          NaN          NaN          NaN          NaN     0.729333
# 2010-01-05          NaN          NaN          NaN          NaN          NaN
#
#             rhr-7_td-18  rhr-11_td-17  rhr-11_td-18  rhr-12_td-17  \
# Datetime
# 2010-01-01       2.0505        -0.246        -0.092      1.836333
# 2010-01-02          NaN         0.912         1.273           NaN
# 2010-01-03          NaN           NaN           NaN           NaN
# 2010-01-04       0.9190         0.901         1.135           NaN
# 2010-01-05          NaN           NaN           NaN           NaN
#
#             rhr-12_td-18  rhr-13_td-17  rhr-13_td-18  rhr-14_td-17  \
# Datetime
# 2010-01-01         1.962     -0.567500     -0.503500       -0.2460
# 2010-01-02           NaN           NaN           NaN           NaN
# 2010-01-03           NaN     -0.869333     -1.160333           NaN
# 2010-01-04           NaN      0.968000      1.240500           NaN
# 2010-01-05           NaN           NaN           NaN        0.6005
#
#             rhr-14_td-18  rhr-15_td-17  rhr-15_td-18  rhr-16_td-17  \
# Datetime
# 2010-01-01        -0.092     -0.049333        -0.431       -0.5675
# 2010-01-02           NaN           NaN           NaN           NaN
# 2010-01-03           NaN           NaN           NaN           NaN
# 2010-01-04           NaN           NaN           NaN           NaN
# 2010-01-05         0.530           NaN           NaN           NaN
#
#             rhr-16_td-18  rhr-21_td-17  rhr-21_td-18
# Datetime
# 2010-01-01       -0.5035      1.836333      1.962000
# 2010-01-02           NaN           NaN           NaN
# 2010-01-03           NaN           NaN           NaN
# 2010-01-04           NaN           NaN           NaN
# 2010-01-05           NaN      0.772000      0.740333

# %% [markdown]
# ## HI/LOs

# %%
hilos = []
for v in ['high_tide', 'high_high_tide', 'low_tide', 'low_low_tide']:
    hilos.append(daily_pivot_table(v, np.mean, "".join(w[0] for w in v.split('_'))))

# %%
hilo_df = pd.concat(hilos, axis=1)
hilo_df.head()
# Out:
#             ht-17  ht-18  hht-17  hht-18  lt-17  lt-18  llt-17  llt-18
# Datetime
# 2010-01-01  1.952  2.241   2.493  2.7490 -0.797 -1.043  -1.198  -1.430
# 2010-01-02    NaN    NaN   1.939  2.2395 -0.604 -0.840  -1.056  -1.132
# 2010-01-03  0.830  1.096     NaN     NaN -1.841 -2.024  -2.516  -2.694
# 2010-01-04    NaN    NaN   1.102  1.3190 -1.693 -1.949  -2.349  -2.566
# 2010-01-05  1.355  1.654   1.480  1.7680 -1.253 -1.453  -1.306  -1.522

# %% [markdown]
# #  Wind

# %%
wind_dfs = []
for v in ['WDF2', 'WSF2', 'AWDR', 'AWND', 'WGF6', 'WSF6', 'WDF6']:
    wind_dfs.append(daily_pivot_table(v, np.mean, v))
all_wind = pd.concat(wind_dfs, axis=1)
all_wind.head()
# Out:
#             WDF2-3  WDF2-19  WDF2-20  WSF2-3  WSF2-19  WSF2-20  AWDR-19  \
# Datetime
# 2010-01-01     NaN    360.0    340.0     NaN     23.0     23.9    353.0
# 2010-01-02     NaN    340.0    310.0     NaN     23.9     30.0    321.0
# 2010-01-03     NaN    290.0    290.0     NaN     17.9     28.0    295.0
# 2010-01-04     NaN    330.0    310.0     NaN     16.1     21.0    306.0
# 2010-01-05     NaN    310.0    300.0     NaN     15.0     17.0    292.0
#
#             AWND-19  AWND-20    WGF6-18    WSF6-18     WDF6-18
# Datetime
# 2010-01-01      6.3      7.2   6.798833   4.384917  201.898458
# 2010-01-02     13.9     19.9  18.064142  11.356569  337.813724
# 2010-01-03     11.2     16.6  16.935208  10.734083  325.094250
# 2010-01-04      7.2      9.8   9.317000   6.280500  324.969875
# 2010-01-05      6.0      8.5   8.925750   6.063000  317.637125

# %%
feature_df = pd.concat([all_wind, hilo_df, td_r15mx, td_rhrmx, tide_df, gw_df, r15_mx, rhr_mx, rain_daily_comb_named, rain_prev_3_days], axis=1)
feature_df = feature_df.loc['2010-09-15':'2016-10-15']
feature_df.head()
# Out:
#             WDF2-3  WDF2-19  WDF2-20  WSF2-3  WSF2-19  WSF2-20  AWDR-19  \
# Datetime
# 2010-09-15     NaN    140.0    110.0     NaN     13.0     15.0    119.0
# 2010-09-16     NaN    220.0    200.0     NaN     25.9     19.9    210.0
# 2010-09-17     NaN    220.0    200.0     NaN     21.0     16.1     41.0
# 2010-09-18     NaN     30.0     30.0     NaN     16.1     18.1     37.0
# 2010-09-19     NaN     40.0     10.0     NaN     10.1     12.1     58.0
#
#             AWND-19  AWND-20  WGF6-18      ...       r3d-1  r3d-2  \
# Datetime                                   ...
# 2010-09-15      5.1      5.6      NaN      ...         NaN    NaN
# 2010-09-16     15.2      9.6      NaN      ...         NaN    NaN
# 2010-09-17     11.0      9.4      NaN      ...         NaN    NaN
# 2010-09-18      8.5      9.4      NaN      ...         NaN    NaN
# 2010-09-19      4.3      4.7      NaN      ...         NaN    NaN
#
#                    r3d-7        r3d-11        r3d-12        r3d-13  \
# Datetime
# 2010-09-15  2.200000e-01  2.400000e-01  2.600000e-01  2.200000e-01
# 2010-09-16  1.000000e-02 -3.053113e-16 -2.220446e-16 -3.608225e-16
# 2010-09-17 -1.351350e-15 -3.053113e-16 -2.220446e-16 -3.608225e-16
# 2010-09-18 -1.351350e-15 -3.053113e-16 -2.220446e-16 -3.608225e-16
# 2010-09-19 -1.351350e-15 -3.053113e-16 -2.220446e-16 -3.608225e-16
#
#                   r3d-14        r3d-15        r3d-16        r3d-21
# Datetime
# 2010-09-15  3.100000e-01  2.400000e-01  3.600000e-01  2.400000e-01
# 2010-09-16  3.330669e-16 -1.110223e-15 -1.554312e-15 -5.551115e-17
# 2010-09-17  3.330669e-16 -1.110223e-15 -1.554312e-15 -5.551115e-17
# 2010-09-18  3.330669e-16 -1.110223e-15 -1.554312e-15 -5.551115e-17
# 2010-09-19  3.330669e-16 -1.110223e-15 -1.554312e-15 -5.551115e-17
#
# [5 rows x 113 columns]

# %% [markdown]
# ### Save Daily Observations to DB

# %%
con = sqlite3.connect(db_filename)
feature_df.to_sql(con=con, name="nor_daily_observations", if_exists="replace")

# %% [markdown]
# ### Make av. table

# %%
cols = pd.Series(feature_df.columns)
cols_splt = cols.str.split('-', expand=True)
col_vars = cols_splt[0].unique()
col_vars
# Out:
# array(['WDF2', 'WSF2', 'AWDR', 'AWND', 'WGF6', 'WSF6', 'WDF6', 'ht', 'hht',
#        'lt', 'llt', 'r15', 'rhr', 'td_av', 'gw_av', 'r15mx', 'rhrmx', 'rd',
#        'r3d'], dtype=object)

# %%
avdf = pd.DataFrame()
for v in col_vars:
    avdf[v] = feature_df[[a for a in feature_df.columns if a.startswith(v)]].mean(axis=1)

# %%
avdf.to_sql(con=con, name='nor_daily_observations_ave', if_exists='replace')

# %%
avdf.head(10)
# Out:
#              WDF2   WSF2   AWDR   AWND  WGF6  WSF6  WDF6      ht      hht  \
# Datetime
# 2010-09-15  125.0  14.00  119.0   5.35   NaN   NaN   NaN  1.5470  1.91250
# 2010-09-16  210.0  22.90  210.0  12.40   NaN   NaN   NaN  1.2205  1.45200
# 2010-09-17  210.0  18.55   41.0  10.20   NaN   NaN   NaN  0.8865      NaN
# 2010-09-18   30.0  17.10   37.0   8.95   NaN   NaN   NaN     NaN  1.63575
# 2010-09-19   25.0  11.10   58.0   4.50   NaN   NaN   NaN  1.7275  2.01750
# 2010-09-20   15.0  22.45   29.0  10.20   NaN   NaN   NaN  1.8965  2.35750
# 2010-09-21  135.0  14.10   79.0   7.05   NaN   NaN   NaN  2.0685  1.97500
# 2010-09-22  220.0  18.00  209.0   9.95   NaN   NaN   NaN  1.4095  1.43500
# 2010-09-23  155.0  15.00  205.0   6.80   NaN   NaN   NaN  1.3130      NaN
# 2010-09-24  200.0  18.45  221.0  10.75   NaN   NaN   NaN  1.2815  1.76700
#
#                  lt     llt  r15           rhr     td_av     gw_av  r15mx  \
# Datetime
# 2010-09-15 -0.58400 -0.6040  0.0 -5.418842e-16  0.630327  1.439483    0.0
# 2010-09-16 -0.86250 -1.1680  0.0 -5.418842e-16  0.317994  1.424287    0.0
# 2010-09-17      NaN -1.1715  0.0 -5.418842e-16 -0.033356  1.405075    0.0
# 2010-09-18 -0.83650 -0.6790  0.0 -5.418842e-16  0.517577  1.373122    0.0
# 2010-09-19 -0.51350 -0.4510  0.0 -5.418842e-16  0.729448  1.365681    0.0
# 2010-09-20 -0.22625     NaN  0.0 -5.418842e-16  1.034590  1.354308    0.0
# 2010-09-21 -0.52650 -0.2280  0.0 -5.418842e-16  0.843558  1.314162    0.0
# 2010-09-22 -0.83500 -0.7875  0.0 -5.418842e-16  0.290825  1.293849    0.0
# 2010-09-23 -1.29600 -1.5320  0.0 -5.418842e-16 -0.065860  1.272830    0.0
# 2010-09-24 -0.94350 -1.3925  0.0 -5.418842e-16  0.213317  1.263802    0.0
#
#                    rhrmx   rd           r3d
# Datetime
# 2010-09-15 -5.418842e-16  0.0  2.570000e-01
# 2010-09-16 -5.418842e-16  0.0  1.000000e-03
# 2010-09-17 -5.418842e-16  0.0  6.499332e-14
# 2010-09-18 -5.418842e-16  0.0  6.499332e-14
# 2010-09-19 -5.418842e-16  0.0  6.499332e-14
# 2010-09-20 -5.418842e-16  0.0  6.499332e-14
# 2010-09-21 -5.418842e-16  0.0  6.499332e-14
# 2010-09-22 -5.418842e-16  0.0  6.499332e-14
# 2010-09-23 -5.418842e-16  0.0  6.499332e-14
# 2010-09-24 -5.418842e-16  0.0  6.499332e-14
